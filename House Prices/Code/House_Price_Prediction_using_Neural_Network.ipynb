# %%
import pandas as pd

# %%
data_train = pd.read_csv('https://raw.githubusercontent.com/imdwipayana/Final-Project/main/House%20Prices/train.csv')

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data_test = pd.read_csv('https://raw.githubusercontent.com/imdwipayana/Final-Project/main/House%20Prices/test.csv')

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
# ...

# %%
for col in data_train:
    print(f'{col} data kosong sebanyak {data_train[col].isnull().sum()}')
# Out:
# Id data kosong sebanyak 0
# MSSubClass data kosong sebanyak 0
# MSZoning data kosong sebanyak 0
# LotFrontage data kosong sebanyak 259
# LotArea data kosong sebanyak 0
# Street data kosong sebanyak 0
# Alley data kosong sebanyak 1369
# LotShape data kosong sebanyak 0
# LandContour data kosong sebanyak 0
# Utilities data kosong sebanyak 0
# LotConfig data kosong sebanyak 0
# LandSlope data kosong sebanyak 0
# Neighborhood data kosong sebanyak 0
# Condition1 data kosong sebanyak 0
# Condition2 data kosong sebanyak 0
# BldgType data kosong sebanyak 0
# HouseStyle data kosong sebanyak 0
# OverallQual data kosong sebanyak 0
# OverallCond data kosong sebanyak 0
# YearBuilt data kosong sebanyak 0
# YearRemodAdd data kosong sebanyak 0
# RoofStyle data kosong sebanyak 0
# RoofMatl data kosong sebanyak 0
# Exterior1st data kosong sebanyak 0
# Exterior2nd data kosong sebanyak 0
# MasVnrType data kosong sebanyak 8
# MasVnrArea data kosong sebanyak 8
# ExterQual data kosong sebanyak 0
# ...

# %%
for col in data_test:
    print(f'{col} data kosong sebanyak {data_train[col].isnull().sum()}')
# Out:
# Id data kosong sebanyak 0
# MSSubClass data kosong sebanyak 0
# MSZoning data kosong sebanyak 0
# LotFrontage data kosong sebanyak 259
# LotArea data kosong sebanyak 0
# Street data kosong sebanyak 0
# Alley data kosong sebanyak 1369
# LotShape data kosong sebanyak 0
# LandContour data kosong sebanyak 0
# Utilities data kosong sebanyak 0
# LotConfig data kosong sebanyak 0
# LandSlope data kosong sebanyak 0
# Neighborhood data kosong sebanyak 0
# Condition1 data kosong sebanyak 0
# Condition2 data kosong sebanyak 0
# BldgType data kosong sebanyak 0
# HouseStyle data kosong sebanyak 0
# OverallQual data kosong sebanyak 0
# OverallCond data kosong sebanyak 0
# YearBuilt data kosong sebanyak 0
# YearRemodAdd data kosong sebanyak 0
# RoofStyle data kosong sebanyak 0
# RoofMatl data kosong sebanyak 0
# Exterior1st data kosong sebanyak 0
# Exterior2nd data kosong sebanyak 0
# MasVnrType data kosong sebanyak 8
# MasVnrArea data kosong sebanyak 8
# ExterQual data kosong sebanyak 0
# ...

# %%
new_train = data_train[['Street','LotShape','LandContour','LotConfig','LandSlope','BldgType','HouseStyle','RoofStyle','RoofMatl','SalePrice']]
new_train.head()
# Out:
#   Street LotShape LandContour LotConfig LandSlope BldgType HouseStyle  \
# 0   Pave      Reg         Lvl    Inside       Gtl     1Fam     2Story
# 1   Pave      Reg         Lvl       FR2       Gtl     1Fam     1Story
# 2   Pave      IR1         Lvl    Inside       Gtl     1Fam     2Story
# 3   Pave      IR1         Lvl    Corner       Gtl     1Fam     2Story
# 4   Pave      IR1         Lvl       FR2       Gtl     1Fam     2Story
#
#   RoofStyle RoofMatl  SalePrice
# 0     Gable  CompShg     208500
# 1     Gable  CompShg     181500
# 2     Gable  CompShg     223500
# 3     Gable  CompShg     140000
# 4     Gable  CompShg     250000

# %%
new_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Street       1460 non-null   object
#  1   LotShape     1460 non-null   object
#  2   LandContour  1460 non-null   object
#  3   LotConfig    1460 non-null   object
#  4   LandSlope    1460 non-null   object
#  5   BldgType     1460 non-null   object
#  6   HouseStyle   1460 non-null   object
#  7   RoofStyle    1460 non-null   object
#  8   RoofMatl     1460 non-null   object
#  9   SalePrice    1460 non-null   int64
# dtypes: int64(1), object(9)
# memory usage: 114.2+ KB

# %%
new_train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
new_train.loc[new_train['SalePrice'] <= 50000, 'SalePrice'] = 0

# %%
new_train.loc[(new_train['SalePrice'] > 50000) & (new_train['SalePrice'] <= 100000), 'SalePrice'] = 1

# %%
new_train.loc[(new_train['SalePrice'] > 100000) & (new_train['SalePrice'] <= 150000), 'SalePrice'] = 2

# %%
new_train.loc[(new_train['SalePrice'] > 150000) & (new_train['SalePrice'] <= 200000), 'SalePrice'] = 3

# %%
new_train.loc[(new_train['SalePrice'] > 200000) & (new_train['SalePrice'] <= 250000), 'SalePrice'] = 4

# %%
new_train.loc[(new_train['SalePrice'] > 250000) & (new_train['SalePrice'] <= 300000), 'SalePrice'] = 5

# %%
new_train.loc[(new_train['SalePrice'] > 300000) & (new_train['SalePrice'] <= 350000), 'SalePrice'] = 6

# %%
new_train.loc[(new_train['SalePrice'] > 350000) & (new_train['SalePrice'] <= 400000), 'SalePrice'] = 7

# %%
new_train.loc[(new_train['SalePrice'] > 400000) & (new_train['SalePrice'] <= 450000), 'SalePrice'] = 8

# %%
new_train.loc[(new_train['SalePrice'] > 450000) & (new_train['SalePrice'] <= 500000), 'SalePrice'] = 9

# %%
new_train.loc[new_train['SalePrice'] > 500000, 'SalePrice'] = 10

# %%
new_train.head(50)
# Out:
#    Street LotShape LandContour LotConfig LandSlope BldgType HouseStyle  \
# 0    Pave      Reg         Lvl    Inside       Gtl     1Fam     2Story
# 1    Pave      Reg         Lvl       FR2       Gtl     1Fam     1Story
# 2    Pave      IR1         Lvl    Inside       Gtl     1Fam     2Story
# 3    Pave      IR1         Lvl    Corner       Gtl     1Fam     2Story
# 4    Pave      IR1         Lvl       FR2       Gtl     1Fam     2Story
# 5    Pave      IR1         Lvl    Inside       Gtl     1Fam     1.5Fin
# 6    Pave      Reg         Lvl    Inside       Gtl     1Fam     1Story
# 7    Pave      IR1         Lvl    Corner       Gtl     1Fam     2Story
# 8    Pave      Reg         Lvl    Inside       Gtl     1Fam     1.5Fin
# 9    Pave      Reg         Lvl    Corner       Gtl   2fmCon     1.5Unf
# 10   Pave      Reg         Lvl    Inside       Gtl     1Fam     1Story
# 11   Pave      IR1         Lvl    Inside       Gtl     1Fam     2Story
# ...

# %%
new_train['SalePrice'].value_counts()
# Out:
# 2     496
# 3     414
# 4     210
# 1     118
# 5     102
# 6      61
# 7      26
# 8      14
# 10      9
# 0       5
# 9       5
# Name: SalePrice, dtype: int64

# %%
new_test = data_test[['Street','LotShape','LandContour','LotConfig','LandSlope','BldgType','HouseStyle','RoofStyle','RoofMatl']]
new_test.head()
# Out:
#   Street LotShape LandContour LotConfig LandSlope BldgType HouseStyle  \
# 0   Pave      Reg         Lvl    Inside       Gtl     1Fam     1Story
# 1   Pave      IR1         Lvl    Corner       Gtl     1Fam     1Story
# 2   Pave      IR1         Lvl    Inside       Gtl     1Fam     2Story
# 3   Pave      IR1         Lvl    Inside       Gtl     1Fam     2Story
# 4   Pave      IR1         HLS    Inside       Gtl   TwnhsE     1Story
#
#   RoofStyle RoofMatl
# 0     Gable  CompShg
# 1       Hip  CompShg
# 2     Gable  CompShg
# 3     Gable  CompShg
# 4     Gable  CompShg

# %%
new_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Street       1459 non-null   object
#  1   LotShape     1459 non-null   object
#  2   LandContour  1459 non-null   object
#  3   LotConfig    1459 non-null   object
#  4   LandSlope    1459 non-null   object
#  5   BldgType     1459 non-null   object
#  6   HouseStyle   1459 non-null   object
#  7   RoofStyle    1459 non-null   object
#  8   RoofMatl     1459 non-null   object
# dtypes: object(9)
# memory usage: 102.7+ KB

# %%
def print_unique_col_values(df):
    for column in df:
        if df[column].dtypes=='object':
            print(f'{column}: {df[column].unique()}')

# %%
print_unique_col_values(new_train)
# Out:
# Street: ['Pave' 'Grvl']
# LotShape: ['Reg' 'IR1' 'IR2' 'IR3']
# LandContour: ['Lvl' 'Bnk' 'Low' 'HLS']
# LotConfig: ['Inside' 'FR2' 'Corner' 'CulDSac' 'FR3']
# LandSlope: ['Gtl' 'Mod' 'Sev']
# BldgType: ['1Fam' '2fmCon' 'Duplex' 'TwnhsE' 'Twnhs']
# HouseStyle: ['2Story' '1Story' '1.5Fin' '1.5Unf' 'SFoyer' 'SLvl' '2.5Unf' '2.5Fin']
# RoofStyle: ['Gable' 'Hip' 'Gambrel' 'Mansard' 'Flat' 'Shed']
# RoofMatl: ['CompShg' 'WdShngl' 'Metal' 'WdShake' 'Membran' 'Tar&Grv' 'Roll'
#  'ClyTile']

# %%
print_unique_col_values(new_test)
# Out:
# Street: ['Pave' 'Grvl']
# LotShape: ['Reg' 'IR1' 'IR2' 'IR3']
# LandContour: ['Lvl' 'HLS' 'Bnk' 'Low']
# LotConfig: ['Inside' 'Corner' 'FR2' 'CulDSac' 'FR3']
# LandSlope: ['Gtl' 'Mod' 'Sev']
# BldgType: ['1Fam' 'TwnhsE' 'Twnhs' 'Duplex' '2fmCon']
# HouseStyle: ['1Story' '2Story' 'SLvl' '1.5Fin' 'SFoyer' '2.5Unf' '1.5Unf']
# RoofStyle: ['Gable' 'Hip' 'Gambrel' 'Flat' 'Mansard' 'Shed']
# RoofMatl: ['CompShg' 'Tar&Grv' 'WdShake' 'WdShngl']

# %%
df_train = pd.get_dummies(data=new_train, columns=['Street','LotShape','LandContour','LotConfig','LandSlope','BldgType','HouseStyle','RoofStyle','RoofMatl'])

# %%
df_test = pd.get_dummies(data=new_test, columns=['Street','LotShape','LandContour','LotConfig','LandSlope','BldgType','HouseStyle','RoofStyle','RoofMatl'])

# %%
df_train.columns
# Out:
# Index(['SalePrice', 'Street_Grvl', 'Street_Pave', 'LotShape_IR1',
#        'LotShape_IR2', 'LotShape_IR3', 'LotShape_Reg', 'LandContour_Bnk',
#        'LandContour_HLS', 'LandContour_Low', 'LandContour_Lvl',
#        'LotConfig_Corner', 'LotConfig_CulDSac', 'LotConfig_FR2',
#        'LotConfig_FR3', 'LotConfig_Inside', 'LandSlope_Gtl', 'LandSlope_Mod',
#        'LandSlope_Sev', 'BldgType_1Fam', 'BldgType_2fmCon', 'BldgType_Duplex',
#        'BldgType_Twnhs', 'BldgType_TwnhsE', 'HouseStyle_1.5Fin',
#        'HouseStyle_1.5Unf', 'HouseStyle_1Story', 'HouseStyle_2.5Fin',
#        'HouseStyle_2.5Unf', 'HouseStyle_2Story', 'HouseStyle_SFoyer',
#        'HouseStyle_SLvl', 'RoofStyle_Flat', 'RoofStyle_Gable',
#        'RoofStyle_Gambrel', 'RoofStyle_Hip', 'RoofStyle_Mansard',
#        'RoofStyle_Shed', 'RoofMatl_ClyTile', 'RoofMatl_CompShg',
#        'RoofMatl_Membran', 'RoofMatl_Metal', 'RoofMatl_Roll',
#        'RoofMatl_Tar&Grv', 'RoofMatl_WdShake', 'RoofMatl_WdShngl'],
# ...

# %%
df_train.dtypes
# Out:
# SalePrice            int64
# Street_Grvl          uint8
# Street_Pave          uint8
# LotShape_IR1         uint8
# LotShape_IR2         uint8
# LotShape_IR3         uint8
# LotShape_Reg         uint8
# LandContour_Bnk      uint8
# LandContour_HLS      uint8
# LandContour_Low      uint8
# LandContour_Lvl      uint8
# LotConfig_Corner     uint8
# LotConfig_CulDSac    uint8
# LotConfig_FR2        uint8
# LotConfig_FR3        uint8
# LotConfig_Inside     uint8
# LandSlope_Gtl        uint8
# LandSlope_Mod        uint8
# LandSlope_Sev        uint8
# BldgType_1Fam        uint8
# BldgType_2fmCon      uint8
# BldgType_Duplex      uint8
# BldgType_Twnhs       uint8
# BldgType_TwnhsE      uint8
# HouseStyle_1.5Fin    uint8
# HouseStyle_1.5Unf    uint8
# HouseStyle_1Story    uint8
# HouseStyle_2.5Fin    uint8
# HouseStyle_2.5Unf    uint8
# HouseStyle_2Story    uint8
# HouseStyle_SFoyer    uint8
# HouseStyle_SLvl      uint8
# RoofStyle_Flat       uint8
# RoofStyle_Gable      uint8
# ...

# %%
X_train = df_train.drop('SalePrice',axis='columns')
y_train = df_train['SalePrice']
X_test = df_test

# %%
len(X_train.columns)
# Out:
# 45

# %%
y_train.value_counts()
# Out:
# 2     496
# 3     414
# 4     210
# 1     118
# 5     102
# 6      61
# 7      26
# 8      14
# 10      9
# 0       5
# 9       5
# Name: SalePrice, dtype: int64

# %%
y_train
# Out:
# 0       4
# 1       3
# 2       4
# 3       2
# 4       4
#        ..
# 1455    3
# 1456    4
# 1457    5
# 1458    2
# 1459    2
# Name: SalePrice, Length: 1460, dtype: int64

# %%
# Build a model (ANN) in Tensorflow/Keras
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.Sequential([
    keras.layers.Dense(64,input_shape=(45,),activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(11,activation='sigmoid')
])

# %%
# opt = keras.optimizer.Adam(learning_rate=0.01)
model.compile(optimizer='adam',
             loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False),
             metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=100)
# Out:
# Epoch 1/100
# 46/46 [==============================] - 1s 2ms/step - loss: 2.0463 - accuracy: 0.2705
# Epoch 2/100
# 46/46 [==============================] - 0s 2ms/step - loss: 1.7140 - accuracy: 0.3658
# Epoch 3/100
# 46/46 [==============================] - 0s 2ms/step - loss: 1.6424 - accuracy: 0.4062
# Epoch 4/100
# 46/46 [==============================] - 0s 1ms/step - loss: 1.6005 - accuracy: 0.4178
# Epoch 5/100
# 46/46 [==============================] - 0s 1ms/step - loss: 1.5699 - accuracy: 0.4226
# Epoch 6/100
# 46/46 [==============================] - 0s 1ms/step - loss: 1.5406 - accuracy: 0.4226
# Epoch 7/100
# 46/46 [==============================] - 0s 1ms/step - loss: 1.5239 - accuracy: 0.4267
# Epoch 8/100
# 46/46 [==============================] - 0s 1ms/step - loss: 1.5017 - accuracy: 0.4342
# Epoch 9/100
# 46/46 [==============================] - 0s 1ms/step - loss: 1.4821 - accuracy: 0.4349
# Epoch 10/100
# ...
